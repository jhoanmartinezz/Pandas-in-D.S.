# %%
import pandas as pd

# %%
#data = "pokemon_data.csv"
#df = pd.read_csv(data)
#df.head()

# %%
#Reading data with issue
data_1 = pd.read_csv("pokemon_data.txt")
data_1.head(3)
# Out:
#   #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0  1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 1  2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 2  3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...

# %%
#solvinh the issue with the sep argument
data = "pokemon_data.txt" 
df = pd.read_csv(data, sep="\s+")
df.head(3)
# Out:
#    #       Name   Type       1 Type.1   2  HP  Attack  Defense  Sp. Atk  \
# 0  1  Bulbasaur  Grass  Poison     45  49  49      65       65   45   1
# 1  2    Ivysaur  Grass  Poison     60  62  63      80       80   60   1
# 2  3   Venusaur  Grass  Poison     80  82  83     100      100   80   1
#
#    Sp..1  Def Speed  Generation  Legendary
# 0  FALSE  NaN   NaN         NaN        NaN
# 1  FALSE  NaN   NaN         NaN        NaN
# 2  FALSE  NaN   NaN         NaN        NaN

# %%
df.tail(3)
# Out:
#        #        Name      Type        1 Type.1    2   HP  Attack  Defense  \
# 797  720  HoopaHoopa  Confined  Psychic  Ghost   80  110      60      150
# 798  720  HoopaHoopa   Unbound  Psychic   Dark   80  160      60      170
# 799  721   Volcanion      Fire    Water     80  110  120     130       90
#
#      Sp. Atk Sp..1   Def Speed  Generation  Legendary
# 797  130  70     6  TRUE   NaN         NaN        NaN
# 798  130  80     6  TRUE   NaN         NaN        NaN
# 799   70   6  TRUE   NaN   NaN         NaN        NaN

# %% [markdown]
# # Reading data in pandas | headers - column - row - location

# %%
#header
df.columns
# Out:
# Index(['#', 'Name', 'Type', '1', 'Type.1', '2', 'HP', 'Attack', 'Defense',
#        'Sp.', 'Atk', 'Sp..1', 'Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#read specific column
df['Name'][0:3]
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Name, dtype: object

# %%
df.Name[0:3]
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Name, dtype: object

# %%
#Especific columns
df[['Name','Type','Attack']][0:4]
# Out:
#            Name      Type  Attack
# 0     Bulbasaur     Grass      65
# 1       Ivysaur     Grass      80
# 2      Venusaur     Grass     100
# 3  VenusaurMega  Venusaur     123

# %%
#Info of an entire row or multiples row with range ":"
df.iloc[0:3]
# Out:
#    #       Name   Type       1 Type.1   2  HP  Attack  Defense  Sp. Atk  \
# 0  1  Bulbasaur  Grass  Poison     45  49  49      65       65   45   1
# 1  2    Ivysaur  Grass  Poison     60  62  63      80       80   60   1
# 2  3   Venusaur  Grass  Poison     80  82  83     100      100   80   1
#
#    Sp..1  Def Speed  Generation  Legendary
# 0  FALSE  NaN   NaN         NaN        NaN
# 1  FALSE  NaN   NaN         NaN        NaN
# 2  FALSE  NaN   NaN         NaN        NaN

# %%
#info in a specific row in an especific column
df.iloc[0,7]
# Out:
# 65

# %%
#Iterate over ieach row
for index, row in df.iterrows():
    print(index, row['Defense'])
# Out:
# 0 65
# 1 80
# 2 100
# 3 122
# 4 65
# 5 80
# 6 85
# 7 111
# 8 78
# 9 43
# 10 58
# 11 78
# 12 115
# 13 45
# 14 30
# 15 80
# 16 20
# 17 25
# 18 80
# 19 15
# 20 35
# 21 50
# 22 70
# 23 135
# 24 72
# 25 97
# 26 31
# 27 61
# 28 55
# 29 80
# 30 90
# 31 110
# 32 40
# 33 65
# 34 40
# 35 56
# 36 85
# 37 40
# 38 65
# 39 75
# 40 35
# 41 60
# 42 65
# 43 100
# 44 25
# 45 50
# 46 40
# 47 75
# 48 65
# 49 75
# 50 90
# 51 55
# 52 80
# 53 55
# 54 75
# 55 95
# 56 120
# 57 90
# 58 115
# 59 55
# 60 85
# 61 70
# 62 95
# 63 60
# 64 95
# 65 90
# 66 90
# 67 90
# 68 90
# 69 105
# 70 120
# 71 95
# 72 35
# 73 45
# 74 55
# 75 30
# 76 45
# 77 70
# 78 100
# 79 120
# 80 30
# 81 45
# 82 65
# 83 90
# 84 105
# 85 40
# 86 80
# 87 130
# 88 55
# 89 70
# 90 62
# 91 35
# 92 60
# 93 45
# 94 95
# 95 25
# 96 50
# 97 40
# 98 45
# 99 35
# 100 55
# 101 75
# 102 170
# 103 45
# 104 42
# 105 67
# 106 50
# 107 75
# 108 100
# 109 140
# 110 45
# 111 65
# 112 35
# 113 45
# 114 87
# 115 76
# 116 30
# 117 35
# 118 60
# 119 30
# 120 45
# ...

# %%
#finding specific data textual infromation
df.loc[df['Type']=="Fire"]
# Out:
#        #         Name  Type         1 Type.1    2   HP  Attack  Defense  Sp.  \
# 4      4   Charmander  Fire        39     52   43   60      50       65    1
# 5      5   Charmeleon  Fire        58     64   58   80      65       80    1
# 6      6    Charizard  Fire    Flying     78   84   78     109       85  100
# 42    37       Vulpix  Fire        38     41   40   50      65       65    1
# 43    38    Ninetales  Fire        73     76   75   81     100      100    1
# 63    58    Growlithe  Fire        55     70   45   70      50       60    1
# 64    59     Arcanine  Fire        90    110   80  100      80       95    1
# 83    77       Ponyta  Fire        50     85   55   65      65       90    1
# 84    78     Rapidash  Fire        65    100   70   80      80      105    1
# 135  126       Magmar  Fire        65     95   57  100      85       93    1
# 147  136      Flareon  Fire        65    130   60   95     110       65    1
# ...

# %% [markdown]
# # Dataset numer's, stats infor and Sorting

# %%
df.head(3)
# Out:
#    #       Name   Type       1 Type.1   2  HP  Attack  Defense  Sp. Atk  \
# 0  1  Bulbasaur  Grass  Poison     45  49  49      65       65   45   1
# 1  2    Ivysaur  Grass  Poison     60  62  63      80       80   60   1
# 2  3   Venusaur  Grass  Poison     80  82  83     100      100   80   1
#
#    Sp..1  Def Speed  Generation  Legendary
# 0  FALSE  NaN   NaN         NaN        NaN
# 1  FALSE  NaN   NaN         NaN        NaN
# 2  FALSE  NaN   NaN         NaN        NaN

# %%
df.describe()
# Out:
#                 #          HP      Attack    Defense         Sp.  Generation  \
# count  800.000000  800.000000  800.000000  800.00000  800.000000         0.0
# mean   362.813750   74.276250   72.857500   71.12875   41.832500         NaN
# std    208.343798   33.250104   30.586338   31.25293   41.780485         NaN
# min      1.000000   10.000000   10.000000    5.00000    1.000000         NaN
# 25%    184.750000   50.000000   50.000000   50.00000    3.000000         NaN
# 50%    364.500000   70.000000   67.500000   65.00000   32.000000         NaN
# 75%    539.250000   95.000000   90.000000   90.00000   75.250000         NaN
# max    721.000000  230.000000  230.000000  230.00000  180.000000         NaN
#
#        Legendary
# count        0.0
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN

# %%
df.sort_values('Name')
# Out:
#        #           Name       Type       1  Type.1    2   HP  Attack  Defense  \
# 510  460      Abomasnow      Grass     Ice      90   92   75      92       85
# 511  460  AbomasnowMega  Abomasnow   Grass     Ice   90  132     105      132
# 68    63           Abra    Psychic      25      20   15  105      55       90
# 392  359          Absol       Dark      65     130   60   75      60       75
# 393  359      AbsolMega      Absol    Dark      65  150   60     115       60
# ..   ...            ...        ...     ...     ...  ...  ...     ...      ...
# 632  571        Zoroark       Dark      60     105   60  120      60      105
# 631  570          Zorua       Dark      40      65   40   80      40       65
# 46    41          Zubat     Poison  Flying      40   45   35      30       40
# 695  634       Zweilous       Dark  Dragon      72   85   70      65       70
# 794  718     Zygarde50%      Forme  Dragon  Ground  108  100     121       81
#
# ...

# %%
df.sort_values(['Type.1','HP'], ascending=[0,1])
# Out:
#        #           Name     Type         1   Type.1    2   HP  Attack  \
# 533  479      RotomWash    Rotom  Electric    Water   50   65     107
# 460  413  WormadamTrash    Cloak       Bug    Steel   60   69      95
# 498  448    LucarioMega  Lucario  Fighting    Steel   70  145      88
# 229  212     ScizorMega   Scizor       Bug    Steel   70  150     140
# 616  555  DarmanitanZen     Mode      Fire  Psychic  105   30     105
# ..   ...            ...      ...       ...      ...  ...  ...     ...
# 404  369      Relicanth    Water      Rock      100   90  130      45
# 421  382         Kyogre    Water       100      100   90  150     140
# 139  129       Magikarp    Water        20       10   55   15      20
# 261  242        Blissey   Normal       255       10   10   75     135
# 316  292       Shedinja      Bug     Ghost        1   90   45      30
#
#      Defense  Sp.    Atk  Sp..1    Def Speed  Generation  Legendary
# ...

# %% [markdown]
# # Making changes to the data

# %%
df.head(5)
# Out:
#    #          Name      Type       1  Type.1   2   HP  Attack  Defense  Sp.  \
# 0  1     Bulbasaur     Grass  Poison      45  49   49      65       65   45
# 1  2       Ivysaur     Grass  Poison      60  62   63      80       80   60
# 2  3      Venusaur     Grass  Poison      80  82   83     100      100   80
# 3  3  VenusaurMega  Venusaur   Grass  Poison  80  100     123      122  120
# 4  4    Charmander      Fire      39      52  43   60      50       65    1
#
#      Atk  Sp..1    Def Speed  Generation  Legendary
# 0      1  FALSE    NaN   NaN         NaN        NaN
# 1      1  FALSE    NaN   NaN         NaN        NaN
# 2      1  FALSE    NaN   NaN         NaN        NaN
# 3     80      1  FALSE   NaN         NaN        NaN
# 4  FALSE    NaN    NaN   NaN         NaN        NaN

# %%
df['Total'] = df['Attack'] + df['Defense'] + df['HP'] + df['Sp.']
df.head()
# Out:
#    #          Name      Type       1  Type.1   2   HP  Attack  Defense  Sp.  \
# 0  1     Bulbasaur     Grass  Poison      45  49   49      65       65   45
# 1  2       Ivysaur     Grass  Poison      60  62   63      80       80   60
# 2  3      Venusaur     Grass  Poison      80  82   83     100      100   80
# 3  3  VenusaurMega  Venusaur   Grass  Poison  80  100     123      122  120
# 4  4    Charmander      Fire      39      52  43   60      50       65    1
#
#      Atk  Sp..1    Def Speed  Generation  Legendary  Total
# 0      1  FALSE    NaN   NaN         NaN        NaN    224
# 1      1  FALSE    NaN   NaN         NaN        NaN    283
# 2      1  FALSE    NaN   NaN         NaN        NaN    363
# 3     80      1  FALSE   NaN         NaN        NaN    465
# 4  FALSE    NaN    NaN   NaN         NaN        NaN    176

# %%
df = df.drop(columns=['Total'])
df.head()
# Out:
#    #          Name      Type       1  Type.1   2   HP  Attack  Defense  Sp.  \
# 0  1     Bulbasaur     Grass  Poison      45  49   49      65       65   45
# 1  2       Ivysaur     Grass  Poison      60  62   63      80       80   60
# 2  3      Venusaur     Grass  Poison      80  82   83     100      100   80
# 3  3  VenusaurMega  Venusaur   Grass  Poison  80  100     123      122  120
# 4  4    Charmander      Fire      39      52  43   60      50       65    1
#
#      Atk  Sp..1    Def Speed  Generation  Legendary
# 0      1  FALSE    NaN   NaN         NaN        NaN
# 1      1  FALSE    NaN   NaN         NaN        NaN
# 2      1  FALSE    NaN   NaN         NaN        NaN
# 3     80      1  FALSE   NaN         NaN        NaN
# 4  FALSE    NaN    NaN   NaN         NaN        NaN

# %% [markdown]
# # Sum values for several columns

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type', '1', 'Type.1', '2', 'HP', 'Attack', 'Defense',
#        'Sp.', 'Atk', 'Sp..1', 'Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Total'] = df.iloc[:,6:10].sum(axis=1)
df.head()
# Out:
#    #          Name      Type       1  Type.1   2   HP  Attack  Defense  Sp.  \
# 0  1     Bulbasaur     Grass  Poison      45  49   49      65       65   45
# 1  2       Ivysaur     Grass  Poison      60  62   63      80       80   60
# 2  3      Venusaur     Grass  Poison      80  82   83     100      100   80
# 3  3  VenusaurMega  Venusaur   Grass  Poison  80  100     123      122  120
# 4  4    Charmander      Fire      39      52  43   60      50       65    1
#
#      Atk  Sp..1    Def Speed  Generation  Legendary  Total
# 0      1  FALSE    NaN   NaN         NaN        NaN    224
# 1      1  FALSE    NaN   NaN         NaN        NaN    283
# 2      1  FALSE    NaN   NaN         NaN        NaN    363
# 3     80      1  FALSE   NaN         NaN        NaN    465
# 4  FALSE    NaN    NaN   NaN         NaN        NaN    176

# %%
49+65+65+45
# Out:
# 224

# %% [markdown]
# # export data

# %%
df.to_csv("modified_1.csv")

# %%
df.to_csv("modified_2.csv",index=False)

# %%
df.to_excel("modified_3.xlsx")

# %%
df.to_excel("modified_4.xlsx",index=False)

# %%
df.to_csv("modified_5.csv",index=False,sep="\t")

# %% [markdown]
# # Filtering data

# %%
df.loc[(df['Type']=="Grass") | (df['1']=="Poison")]
# Out:
#        #        Name   Type         1 Type.1    2   HP  Attack  Defense  Sp.  \
# 0      1   Bulbasaur  Grass    Poison     45   49   49      65       65   45
# 1      2     Ivysaur  Grass    Poison     60   62   63      80       80   60
# 2      3    Venusaur  Grass    Poison     80   82   83     100      100   80
# 16    13      Weedle    Bug    Poison     40   35   30      20       20   50
# 17    14      Kakuna    Bug    Poison     45   25   50      25       25   35
# ..   ...         ...    ...       ...    ...  ...  ...     ...      ...  ...
# 718  650     Chespin  Grass        56     61   65   48      45       38    6
# 719  651   Quilladin  Grass        61     78   95   56      58       57    6
# 720  652  Chesnaught  Grass  Fighting     88  107  122      74       75   64
# 740  672      Skiddo  Grass        66     65   48   62      57       52    6
# 741  673      Gogoat  Grass       123    100   62   97      81       68    6
#
# ...

# %% [markdown]
# # reset index to zero

# %%
df.loc[(df['Type']=="Grass") & (df['1']=="Poison")]
# Out:
#        #        Name   Type       1 Type.1    2  HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur  Grass  Poison     45   49  49      65       65   45   1
# 1      2     Ivysaur  Grass  Poison     60   62  63      80       80   60   1
# 2      3    Venusaur  Grass  Poison     80   82  83     100      100   80   1
# 48    43      Oddish  Grass  Poison     45   50  55      75       65   30   1
# 49    44       Gloom  Grass  Poison     60   65  70      85       75   40   1
# 50    45   Vileplume  Grass  Poison     75   80  85     110       90   50   1
# 75    69  Bellsprout  Grass  Poison     50   75  35      70       30   40   1
# 76    70  Weepinbell  Grass  Poison     65   90  50      85       45   55   1
# 77    71  Victreebel  Grass  Poison     80  105  65     100       70   70   1
# 344  315     Roselia  Grass  Poison     50   60  45     100       80   65   3
# 451  406       Budew  Grass  Poison     40   30  35      50       70   55   4
# ...

# %%
new_df = df.loc[(df['Type']=="Grass") & (df['1']=="Poison")]
new_df.to_csv('filtered.csv')
new_df.head(2)
# Out:
#    #       Name   Type       1 Type.1   2  HP  Attack  Defense  Sp. Atk  \
# 0  1  Bulbasaur  Grass  Poison     45  49  49      65       65   45   1
# 1  2    Ivysaur  Grass  Poison     60  62  63      80       80   60   1
#
#    Sp..1  Def Speed  Generation  Legendary  Total
# 0  FALSE  NaN   NaN         NaN        NaN    224
# 1  FALSE  NaN   NaN         NaN        NaN    283

# %%
df.loc[df['Name'].str.contains('Gloom|Roselia')]
# Out:
#        #     Name   Type       1 Type.1   2  HP  Attack  Defense  Sp. Atk  \
# 49    44    Gloom  Grass  Poison     60  65  70      85       75   40   1
# 344  315  Roselia  Grass  Poison     50  60  45     100       80   65   3
#
#      Sp..1  Def Speed  Generation  Legendary  Total
# 49   FALSE  NaN   NaN         NaN        NaN    270
# 344  FALSE  NaN   NaN         NaN        NaN    290

# %%
new_df = new_df.reset_index(drop=True)
new_df.tail(3)
# Out:
#       #       Name   Type       1 Type.1   2  HP  Attack  Defense  Sp. Atk  \
# 11  407   Roserade  Grass  Poison     60  70  65     125      105   90   4
# 12  590    Foongus  Grass  Poison     69  55  45      55       55   15   5
# 13  591  Amoonguss  Grass  Poison    114  85  70      85       80   30   5
#
#     Sp..1  Def Speed  Generation  Legendary  Total
# 11  FALSE  NaN   NaN         NaN        NaN    385
# 12  FALSE  NaN   NaN         NaN        NaN    170
# 13  FALSE  NaN   NaN         NaN        NaN    265

# %% [markdown]
# # Conditional Changes

# %%
df.loc[df['Type'] == 'Fire', 'Legendary'] = True
df.head()
# Out:
#    #          Name      Type       1  Type.1   2   HP  Attack  Defense  Sp.  \
# 0  1     Bulbasaur     Grass  Poison      45  49   49      65       65   45
# 1  2       Ivysaur     Grass  Poison      60  62   63      80       80   60
# 2  3      Venusaur     Grass  Poison      80  82   83     100      100   80
# 3  3  VenusaurMega  Venusaur   Grass  Poison  80  100     123      122  120
# 4  4    Charmander      Fire      39      52  43   60      50       65    1
#
#      Atk  Sp..1    Def Speed  Generation Legendary  Total
# 0      1  FALSE    NaN   NaN         NaN       NaN    224
# 1      1  FALSE    NaN   NaN         NaN       NaN    283
# 2      1  FALSE    NaN   NaN         NaN       NaN    363
# 3     80      1  FALSE   NaN         NaN       NaN    465
# 4  FALSE    NaN    NaN   NaN         NaN      True    176

# %%
df.loc[df['Total'] > 500, ['Attack', 'Defense']] = ['Test 1', 'Test 2']
df.tail()
# Out:
#        #         Name      Type        1 Type.1    2   HP  Attack Defense  \
# 795  719      Diancie      Rock    Fairy     50  100  150  Test 1  Test 2
# 796  719  DiancieMega   Diancie     Rock  Fairy   50  160  Test 1  Test 2
# 797  720   HoopaHoopa  Confined  Psychic  Ghost   80  110  Test 1  Test 2
# 798  720   HoopaHoopa   Unbound  Psychic   Dark   80  160  Test 1  Test 2
# 799  721    Volcanion      Fire    Water     80  110  120  Test 1  Test 2
#
#      Sp.  Atk Sp..1   Def Speed  Generation Legendary  Total
# 795   50    6  TRUE   NaN   NaN         NaN       NaN    450
# 796  110  110     6  TRUE   NaN         NaN       NaN    540
# 797  130   70     6  TRUE   NaN         NaN       NaN    450
# 798  130   80     6  TRUE   NaN         NaN       NaN    520
# 799   70    6  TRUE   NaN   NaN         NaN      True    410

# %% [markdown]
# # Agregate Statistics(Groupby)

# %%
df = pd.read_excel('pokemon_data.xlsx')
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.groupby(['Type 1']).mean()
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('HP', ascending=False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Normal    319.173469  77.275510   73.469388   59.846939  55.816327  63.724490
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Psychic   380.807018  70.631579   71.456140   67.684211  98.403509  86.280702
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# ...

# %%
df.groupby(['Type 1']).sum()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Bug       23080  3925    4897     4880     3717     4471   4256         222
# Dark      14302  2071    2740     2177     2314     2155   2361         125
# Dragon    15180  2666    3588     2764     3099     2843   2657         124
# Electric  15994  2631    3040     2917     3961     3243   3718         144
# Fairy      7642  1260    1046     1117     1335     1440    826          70
# Fighting   9824  1886    2613     1780     1434     1747   1784          91
# Fire      17025  3635    4408     3524     4627     3755   3871         167
# Flying     2711   283     315      265      377      290    410          22
# Ghost     15568  2062    2361     2598     2539     2447   2059         134
# Grass     24141  4709    5125     4956     5425     4930   4335         235
# Ground    11401  2361    3064     2715     1807     2008   2045         101
# ...

# %%
df.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    27       7   27      27       27       27       27     27
# Fire       52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...

# %%
df['count'] = 1
df.groupby(['Type 1']).count()['count']
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  count
# 0         65       65     45           1      False      1
# ...

# %%
df['count'] = 1
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# # Working with large amounts of data

# %%
for df in pd.read_csv('pokemon_data.csv',sep="\s+", chunksize=7):
    print("CUHNK DF")
    print(df)
# Out:
# CUHNK DF
#                                          #,Name,Type  \
# 0  1,Bulbasaur,Grass,Poison,45,49,49,65,65,45,1,F...
# 1   2,Ivysaur,Grass,Poison,60,62,63,80,80,60,1,FALSE
# 2  3,Venusaur,Grass,Poison,80,82,83,100,100,80,1,...
# 3                                     3,VenusaurMega
# 4       4,Charmander,Fire,,39,52,43,60,50,65,1,FALSE
# 5       5,Charmeleon,Fire,,58,64,58,80,65,80,1,FALSE
# 6  6,Charizard,Fire,Flying,78,84,78,109,85,100,1,...
#
#                                               1,Type  2,HP,Attack,Defense,Sp.  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3  Venusaur,Grass,Poison,80,100,123,122,120,80,1,...                      NaN
# 4                                                NaN                      NaN
# ...
